# %% [markdown]
# # Listas en Python

# %% [markdown]
# ## 1. ¿Qué es una lista?

# %%
numeros = [1, 2, 3, 4, 5]
nombres = ["Ana", "Luis", "Pedro"]
mezcla = [1, "hola", 3.14, True]

print(numeros)
print(nombres)
print(mezcla)

# %% [markdown]
# ## 2. Acceso a elementos

# %%
lista = [10, 20, 30, 40]

print(lista[0])
print(lista[-1])

# %% [markdown]
# ## 3. Modificar listas

# %%
lista = [1, 2, 3]
lista[1] = 99
print(lista)

# %% [markdown]
# ## 4. Métodos importantes

# %%
lista = [1, 2, 3]

lista.append(4)
lista.insert(1, 10)
lista.remove(2)
ultimo = lista.pop()

print(lista)
print("Elemento eliminado:", ultimo)

# %% [markdown]
# ## 5. Recorrer listas

# %%
for elemento in lista:
    print(elemento)

# %% [markdown]
# ## 6. Funciones útiles

# %%
nums = [4, 2, 8, 1]

print(len(nums))
print(max(nums))
print(min(nums))
print(sum(nums))

# %% [markdown]
# ## 7. Slicing

# %%
nums = [0,1,2,3,4,5]

print(nums[1:4])
print(nums[:3])
print(nums[::2])

# %% [markdown]
# ## 8. Listas con condicionales

# %%
nums = [1,2,3,4,5,6]

for n in nums:
    if n % 2 == 0:
        print(n)

# %% [markdown]
# ## 9. Listas por comprensión

# %%
cuadrados = [x**2 for x in range(10)]
pares = [x for x in range(20) if x % 2 == 0]

print(cuadrados)
print(pares)

# %% [markdown]
# ## 10. Ejercicios

# %% [markdown]
# 1. Crear una lista con 5 números e imprimir el primero y el último.
# 2. Modificar el segundo elemento.
# 3. Agregar un elemento al final.
# 4. Eliminar un número específico.
# 5. Recorrer e imprimir todos los elementos.
# 6. Contar pares.
# 7. Crear lista de cuadrados del 1 al 10.
# 8. Filtrar números mayores a 5.
# 9. Invertir una lista.
# 10. Encontrar máximo y mínimo.
