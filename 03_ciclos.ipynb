# %% [markdown]
# # Ciclos en Python
#
# ## 📌 Objetivos
#
# - Comprender qué es un ciclo
# - Diferenciar `while` y `for`
# - Aplicar ciclos en problemas reales
# - Evitar errores comunes
#
# Muchas veces necesitamos repetir acciones:
#
# - Procesar muchos datos
# - Validar entradas
# - Automatizar tareas
#
# Para eso usamos **ciclos**

# %% [markdown]
# # Ciclo `while`
#
# Repite instrucciones **mientras una condición sea verdadera**.
#
# ## Sintaxis
#
# ```python
# while condicion:
#     # código
# ```

# %%
i = 1

while i <= 5:
    print(i)
    i += 1

# %% [markdown]
# ## Cuidado: loops infinitos
#
# Si la condición nunca cambia → el programa no termina.

# %%
# Ejemplo incorrecto (NO ejecutar indefinidamente)
i = 1
while i <= 5:
    print(i)
    # falta actualizar i

# %% [markdown]
# # Ciclo `for`
#
# Se usa para recorrer secuencias o repetir una cantidad fija de veces.

# %%
for i in range(5):
    print(i)

# %% [markdown]
# ## Uso de range()
#
# - `range(5)` → 0 a 4
# - `range(1,6)` → 1 a 5
# - `range(2,10,2)` → pares

# %%
for i in range(2, 10, 2):
    print(i)

# %% [markdown]
# # Ejemplo: suma acumulada

# %%
suma = 0
for i in range(1, 6):
    suma += i
print("Suma:", suma)

# %% [markdown]
# # Control de ciclos
#
# ## break → corta el ciclo
# ## continue → salta iteración

# %%
for i in range(10):
    if i == 5:
        break
    print(i)

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)

# %% [markdown]
# # 🧪 Ejercicios
#
# ### 🟢 Básicos
#
# 1. Mostrar números del 1 al 10
# 2. Mostrar números pares del 1 al 20
# 3. Pedir 5 números y mostrar la suma
#
# ### 🟡 Intermedios
#
# 4. Pedir números hasta que el usuario ingrese 0
# 5. Contar cuántos números positivos se ingresaron
# 6. Mostrar tabla de multiplicar de un número
# 7. Juego de adivinar número
# 8. Calcular promedio hasta número negativo

# %%
n = 20
for i in range(0, n, 4):
    print(f" {i}")
# Out:
#  0
#  4
#  8
#  12
#  16

# %%
suma = 0

for i in range(1, 6):
    suma = suma + i
print("Suma:", suma)
# Out:
#  0
#  6
#  12
#  18
