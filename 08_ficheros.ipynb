# %% [markdown]
# # Introducción a Pandas
#
#
# Objetivo:
# - Leer archivos CSV
# - Explorar DataFrames
# - Filtrar datos
# - Crear columnas nuevas
# - Agrupar y resumir información
# - Resolver problemas de análisis de datos

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Ejercicio 1 - Cargar datos básicos
#
# Archivo: `ventas_noa_basico.csv`
#
# Resolver:
# 1. Leer el CSV
# 2. Mostrar las primeras filas
# 3. Ver tipos de datos
# 4. Obtener cantidad de registros

# %%
# escribir solución aquí

# %% [markdown]
# ## Ejercicio 2 - Filtros
#
# Con el archivo de ventas:
#
# 1. Mostrar ventas de Salta
# 2. Mostrar productos con cantidad mayor a 20
# 3. Crear una columna `total = cantidad * precio_unitario`
# 4. Ordenar por total descendente

# %%
# escribir solución aquí

# %% [markdown]
# ## Ejercicio 3 - Agrupaciones
#
# Archivo: `produccion_agro_NOA.csv`
#
# Resolver:
# 1. Producción total por provincia
# 2. Producto con mayor producción
# 3. Promedio de hectáreas por provincia
# 4. Filtrar producción del año 2025

# %%
# escribir solución aquí

# %% [markdown]
# ## Ejercicio 4 - Limpieza y análisis
#
# Archivo: `turismo_NOA.csv`
#
# Resolver:
#
# 1. Convertir fecha a datetime
# 2. Obtener visitantes por mes
# 3. Calcular satisfacción promedio por provincia
# 4. Buscar atractivos con más de 5000 visitantes

# %%
# escribir solución aquí

# %% [markdown]
# ## Ejercicio final - Dataset grande
#
# Archivo: `clientes_energia_NOA.csv`
#
# Resolver:
#
# 1. Analizar consumo promedio por provincia
# 2. Comparar clientes con y sin paneles solares
# 3. Crear una clasificación de consumo:
#    - bajo
#    - medio
#    - alto
# 4. Generar un resumen final con agrupaciones

# %%
# escribir solución aquí
